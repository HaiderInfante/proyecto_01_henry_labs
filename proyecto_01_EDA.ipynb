# %% [markdown]
# # Proyecto 01 - EDA - HENRY

# %%
import pandas as pd
import json
import gzip
import re

# %% [markdown]
# ## EDA del df_steam_games

# %%
df_steam_games_v2_EDA = pd.read_csv('04_datasets_proyecto_01_EDA/df_steam_games_v2_EDA.csv')
df_steam_games_v2_EDA
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro  ['Action', 'Casual', 'Indie', 'Simulation', 'S...
# 1      Making Fun, Inc.       ['Free to Play', 'Indie', 'RPG', 'Strategy']
# 2          Poolians.com  ['Casual', 'Free to Play', 'Indie', 'Simulatio...
# 3                  彼岸领域                  ['Action', 'Adventure', 'Casual']
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games      ['Casual', 'Indie', 'Simulation', 'Strategy']
# 32131            Sacada                    ['Casual', 'Indie', 'Strategy']
# 32132      Laush Studio                  ['Indie', 'Racing', 'Simulation']
# 32133          SIXNAILS                                ['Casual', 'Indie']
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %%
df_steam_games_v2_EDA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32135 entries, 0 to 32134
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   publisher       24064 non-null  object
#  1   genres          28852 non-null  object
#  2   app_name        32133 non-null  object
#  3   title           30085 non-null  object
#  4   url             32135 non-null  object
#  5   release_date    30068 non-null  object
#  6   tags            31972 non-null  object
#  7   reviews_url     32133 non-null  object
#  8   discount_price  225 non-null    float64
#  9   specs           31465 non-null  object
#  10  price           30758 non-null  object
#  11  early_access    32135 non-null  float64
#  12  id              32133 non-null  float64
#  13  metascore       2607 non-null   float64
#  14  developer       28836 non-null  object
# dtypes: float64(4), object(11)
# memory usage: 3.7+ MB

# %%
df_steam_games_v2_EDA.describe(include='all')
# Out:
#        publisher      genres    app_name       title  \
# count      24064       28852       32133       30085
# unique      8236         883       32094       30054
# top      Ubisoft  ['Action']  Soundtrack  Soundtrack
# freq         385        1880           3           3
# mean         NaN         NaN         NaN         NaN
# std          NaN         NaN         NaN         NaN
# min          NaN         NaN         NaN         NaN
# 25%          NaN         NaN         NaN         NaN
# 50%          NaN         NaN         NaN         NaN
# 75%          NaN         NaN         NaN         NaN
# max          NaN         NaN         NaN         NaN
#
#                                                       url release_date  \
# count                                               32135        30068
# unique                                              32135         3582
# top     http://store.steampowered.com/app/761140/Lost_...   2012-10-16
# ...

# %%
df_steam_games_v2_EDA['app_name'] = df_steam_games_v2_EDA['app_name'].str.title()

# Verificamos si hay valores duplicados en la columna
num_duplicados = df_steam_games_v2_EDA['app_name'].duplicated().sum()


duplicados = df_steam_games_v2_EDA[df_steam_games_v2_EDA['app_name'].duplicated()]
duplicados
# Out:
#                                                publisher  \
# 1509                                The Sleeping Machine
# 2580                                                 NaN
# 9454                                    Polyraptor Games
# 10840                                            VRotein
# 11922                                          KEA Games
# 13421                                                NaN
# 13653                                      Horizon Games
# 14573                                 Bethesda Softworks
# 14871                                                NaN
# 16455                                                NaN
# 16798                                          interplay
# 18064                                 monkey king studio
# 19063                                 Bigben Interactive
# 19064                                 Bigben Interactive
# 19582                                         Ｌｅｍｏｎ　Ｂａｌｍ
# ...
